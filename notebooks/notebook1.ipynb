# %%
"""
Experiment with RL algos like PPO on the env
"""

from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import EvalCallback
import wandb
from wandb.integration.sb3 import WandbCallback
from cookie_jars.env import CookieJarsEnv

import os
import random
import numpy as np
import torch as th
from stable_baselines3.common.env_checker import check_env

# %%
seed = 42
os.environ['PYTHONHASHSEED']=str(seed) 
random.seed(seed)
np.random.seed(seed)
th.manual_seed(seed)

# %%
env = CookieJarsEnv('train')
check_env(env)
# Out:
# /Users/dennis/repos/cookie-jars/.venv/lib/python3.9/site-packages/stable_baselines3/common/env_checker.py:272: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(

# %%
env = CookieJarsEnv('train')
eval_env = CookieJarsEnv('val')
config = {
    "policy_type": "MlpPolicy",
    "total_timesteps": 5000000,
}
run = wandb.init(
    project="cookiejars-scratch",
    config=config,
    sync_tensorboard=True,  # auto-upload sb3's tensorboard metrics
    # monitor_gym=True,  # auto-upload the videos of agents playing the game
    # save_code=True,  # optional
)

model = PPO(config["policy_type"], env, verbose=1, tensorboard_log=f"runs/{run.id}")
wandb_callback = WandbCallback(
    model_save_path=f"models/{run.id}",
    verbose=2,
)
eval_callback = EvalCallback(
    eval_env, 
    best_model_save_path='./logs/',
    log_path='./logs/', 
    n_eval_episodes=1,
    eval_freq=25000,
    deterministic=True, 
    render=False,
)
model.learn(
    total_timesteps=config["total_timesteps"],
    callback=[eval_callback, wandb_callback],
)
run.finish()
# Out:
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/Users/dennis/repos/cookie-jars/notebooks/wandb/run-20220310_112244-bzdlbvms</code>
# Syncing run <strong><a href="https://wandb.ai/dennisfeng/cookiejars-scratch/runs/bzdlbvms" target="_blank">fearless-elevator-4</a></strong> to <a href="https://wandb.ai/dennisfeng/cookiejars-scratch" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# wandb: WARNING When using several event log directories, please call wandb.tensorboard.patch(root_logdir="...") before wandb.init
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to runs/bzdlbvms/PPO_1
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.51e+03  |
# |    ep_rew_mean     | -1.79e+04 |
# | time/              |           |
# |    fps             | 1064      |
# |    iterations      | 1         |
# |    time_elapsed    | 1         |
# |    total_timesteps | 2048      |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.78e+04   |
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.020609234 |
# |    clip_fraction        | 0.289       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.76e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.994       |
# |    value_loss           | 3.67e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -1.74e+04  |
# | time/                   |            |
# |    fps                  | 931        |
# |    iterations           | 3          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.02320676 |
# |    clip_fraction        | 0.312      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.3      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.67e+04   |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0194    |
# |    std                  | 0.989      |
# |    value_loss           | 3.5e+04    |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -1.72e+04  |
# | time/                   |            |
# |    fps                  | 920        |
# |    iterations           | 4          |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.02104076 |
# |    clip_fraction        | 0.309      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42.2      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.61e+04   |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0184    |
# |    std                  | 0.985      |
# |    value_loss           | 3.18e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -1.7e+04   |
# | time/                   |            |
# |    fps                  | 900        |
# |    iterations           | 5          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01980962 |
# |    clip_fraction        | 0.294      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -42        |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.4e+04    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0156    |
# |    std                  | 0.976      |
# |    value_loss           | 2.96e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.65e+04   |
# | time/                   |             |
# |    fps                  | 901         |
# |    iterations           | 6           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.020001063 |
# |    clip_fraction        | 0.32        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+04     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0175     |
# |    std                  | 0.971       |
# |    value_loss           | 2.66e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.63e+04   |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 7           |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.023142967 |
# |    clip_fraction        | 0.317       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.13e+04    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0166     |
# |    std                  | 0.966       |
# |    value_loss           | 2.3e+04     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -1.61e+04  |
# | time/                   |            |
# |    fps                  | 840        |
# |    iterations           | 8          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.02375037 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.4      |
# |    explained_variance   | -2.38e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.09e+04   |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0185    |
# |    std                  | 0.96       |
# |    value_loss           | 2.23e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -1.56e+04  |
# | time/                   |            |
# |    fps                  | 845        |
# |    iterations           | 9          |
# |    time_elapsed         | 21         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01856869 |
# |    clip_fraction        | 0.298      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 9.59e+03   |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0166    |
# |    std                  | 0.951      |
# |    value_loss           | 1.96e+04   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -1.54e+04  |
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 10         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 20480      |
# | train/                  |            |
# |    approx_kl            | 0.02174112 |
# |    clip_fraction        | 0.313      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -40.9      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.39e+03   |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0174    |
# |    std                  | 0.942      |
# |    value_loss           | 1.74e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.52e+04   |
# | time/                   |             |
# |    fps                  | 861         |
# |    iterations           | 11          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.023382546 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.47e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.933       |
# |    value_loss           | 1.61e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.48e+04   |
# | time/                   |             |
# |    fps                  | 865         |
# |    iterations           | 12          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.023190487 |
# |    clip_fraction        | 0.301       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -40.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.57e+03    |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.923       |
# |    value_loss           | 1.38e+04    |
# -----------------------------------------
# /Users/dennis/repos/cookie-jars/.venv/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=25000, episode_reward=1120.77 +/- 0.00
# Episode length: 502.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 502         |
# |    mean_reward          | 1.12e+03    |
# | time/                   |             |
# |    total_timesteps      | 25000       |
# | train/                  |             |
# |    approx_kl            | 0.023064734 |
# |    clip_fraction        | 0.3         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.9e+03     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0132     |
# |    std                  | 0.911       |
# |    value_loss           | 1.24e+04    |
# -----------------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.51e+03  |
# |    ep_rew_mean     | -1.46e+04 |
# | time/              |           |
# |    fps             | 859       |
# |    iterations      | 13        |
# |    time_elapsed    | 30        |
# |    total_timesteps | 26624     |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.42e+04   |
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 14          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.025140945 |
# |    clip_fraction        | 0.312       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.23e+03    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0161     |
# |    std                  | 0.904       |
# |    value_loss           | 1.08e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.4e+04    |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 15          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.020051934 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39.3       |
# |    explained_variance   | -2.38e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.71e+03    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0154     |
# |    std                  | 0.894       |
# |    value_loss           | 1e+04       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.38e+04   |
# | time/                   |             |
# |    fps                  | 873         |
# |    iterations           | 16          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.021874119 |
# |    clip_fraction        | 0.303       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -39         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.93e+03    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.884       |
# |    value_loss           | 8.65e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.34e+04   |
# | time/                   |             |
# |    fps                  | 874         |
# |    iterations           | 17          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.024456482 |
# |    clip_fraction        | 0.345       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -38.7       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.36e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.876       |
# |    value_loss           | 7.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.32e+04   |
# | time/                   |             |
# |    fps                  | 876         |
# |    iterations           | 18          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020469965 |
# |    clip_fraction        | 0.309       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -38.5       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.66e+03    |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0114     |
# |    std                  | 0.869       |
# |    value_loss           | 5.98e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.3e+04    |
# | time/                   |             |
# |    fps                  | 879         |
# |    iterations           | 19          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.020949557 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -38.2       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.42e+03    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.861       |
# |    value_loss           | 5.33e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.26e+04   |
# | time/                   |             |
# |    fps                  | 882         |
# |    iterations           | 20          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.028519776 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.07e+03    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.853       |
# |    value_loss           | 4.62e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -1.24e+04  |
# | time/                   |            |
# |    fps                  | 883        |
# |    iterations           | 21         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 43008      |
# | train/                  |            |
# |    approx_kl            | 0.02059092 |
# |    clip_fraction        | 0.318      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37.7      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.95e+03   |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.0142    |
# |    std                  | 0.847      |
# |    value_loss           | 4.08e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.23e+04   |
# | time/                   |             |
# |    fps                  | 885         |
# |    iterations           | 22          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.024870181 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -37.4       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59e+03    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.837       |
# |    value_loss           | 3.57e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -1.19e+04  |
# | time/                   |            |
# |    fps                  | 885        |
# |    iterations           | 23         |
# |    time_elapsed         | 53         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.02506014 |
# |    clip_fraction        | 0.324      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -37        |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.3e+03    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0158    |
# |    std                  | 0.829      |
# |    value_loss           | 3.11e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.18e+04   |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 24          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.020457894 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.8       |
# |    explained_variance   | 1.19e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.15e+03    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00766    |
# |    std                  | 0.825       |
# |    value_loss           | 2.51e+03    |
# -----------------------------------------
# Eval num_timesteps=50000, episode_reward=2031.01 +/- 0.00
# Episode length: 502.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 502         |
# |    mean_reward          | 2.03e+03    |
# | time/                   |             |
# |    total_timesteps      | 50000       |
# | train/                  |             |
# |    approx_kl            | 0.024150666 |
# |    clip_fraction        | 0.324       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.6       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 993         |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.816       |
# |    value_loss           | 2.28e+03    |
# -----------------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.51e+03  |
# |    ep_rew_mean     | -1.16e+04 |
# | time/              |           |
# |    fps             | 883       |
# |    iterations      | 25        |
# |    time_elapsed    | 57        |
# |    total_timesteps | 51200     |
# ----------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.13e+04   |
# | time/                   |             |
# |    fps                  | 885         |
# |    iterations           | 26          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.023081299 |
# |    clip_fraction        | 0.326       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 746         |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.00929    |
# |    std                  | 0.809       |
# |    value_loss           | 1.72e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.12e+04   |
# | time/                   |             |
# |    fps                  | 886         |
# |    iterations           | 27          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.025659602 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -36.1       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 726         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00884    |
# |    std                  | 0.803       |
# |    value_loss           | 1.49e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.09e+04   |
# | time/                   |             |
# |    fps                  | 887         |
# |    iterations           | 28          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.019306868 |
# |    clip_fraction        | 0.293       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.7       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 587         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00681    |
# |    std                  | 0.793       |
# |    value_loss           | 1.15e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.07e+04   |
# | time/                   |             |
# |    fps                  | 888         |
# |    iterations           | 29          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.029775672 |
# |    clip_fraction        | 0.351       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35.4       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 314         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00784    |
# |    std                  | 0.784       |
# |    value_loss           | 1.03e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.06e+04   |
# | time/                   |             |
# |    fps                  | 889         |
# |    iterations           | 30          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.030419063 |
# |    clip_fraction        | 0.325       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -35         |
# |    explained_variance   | 1.79e-07    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 325         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.01       |
# |    std                  | 0.775       |
# |    value_loss           | 722         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -1.03e+04  |
# | time/                   |            |
# |    fps                  | 890        |
# |    iterations           | 31         |
# |    time_elapsed         | 71         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.02924803 |
# |    clip_fraction        | 0.375      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -34.7      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 143        |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00907   |
# |    std                  | 0.765      |
# |    value_loss           | 502        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1.01e+04   |
# | time/                   |             |
# |    fps                  | 891         |
# |    iterations           | 32          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.053787146 |
# |    clip_fraction        | 0.593       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -34.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 559         |
# |    n_updates            | 310         |
# |    policy_gradient_loss | 0.0364      |
# |    std                  | 0.758       |
# |    value_loss           | 1.84e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -1e+04      |
# | time/                   |             |
# |    fps                  | 891         |
# |    iterations           | 33          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.019188773 |
# |    clip_fraction        | 0.248       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -34.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 589         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0173     |
# |    std                  | 0.756       |
# |    value_loss           | 388         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -9.62e+03   |
# | time/                   |             |
# |    fps                  | 892         |
# |    iterations           | 34          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.022447329 |
# |    clip_fraction        | 0.426       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -34         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 353         |
# |    n_updates            | 330         |
# |    policy_gradient_loss | 0.013       |
# |    std                  | 0.751       |
# |    value_loss           | 1.37e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -9.51e+03   |
# | time/                   |             |
# |    fps                  | 891         |
# |    iterations           | 35          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.014217479 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.9       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.19e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00225    |
# |    std                  | 0.75        |
# |    value_loss           | 2.43e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -9.4e+03    |
# | time/                   |             |
# |    fps                  | 891         |
# |    iterations           | 36          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.013128133 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 75.9        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0146     |
# |    std                  | 0.747       |
# |    value_loss           | 376         |
# -----------------------------------------
# Eval num_timesteps=75000, episode_reward=2349.91 +/- 0.00
# Episode length: 502.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 502         |
# |    mean_reward          | 2.35e+03    |
# | time/                   |             |
# |    total_timesteps      | 75000       |
# | train/                  |             |
# |    approx_kl            | 0.015498005 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.7       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 35.9        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00811    |
# |    std                  | 0.744       |
# |    value_loss           | 276         |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | -9.2e+03 |
# | time/              |          |
# |    fps             | 888      |
# |    iterations      | 37       |
# |    time_elapsed    | 85       |
# |    total_timesteps | 75776    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -9.11e+03  |
# | time/                   |            |
# |    fps                  | 890        |
# |    iterations           | 38         |
# |    time_elapsed         | 87         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.04393641 |
# |    clip_fraction        | 0.326      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -33.6      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 121        |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0109    |
# |    std                  | 0.742      |
# |    value_loss           | 467        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -9.01e+03  |
# | time/                   |            |
# |    fps                  | 890        |
# |    iterations           | 39         |
# |    time_elapsed         | 89         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.03404386 |
# |    clip_fraction        | 0.303      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -33.5      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 25.9       |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.0134    |
# |    std                  | 0.735      |
# |    value_loss           | 287        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -8.73e+03  |
# | time/                   |            |
# |    fps                  | 891        |
# |    iterations           | 40         |
# |    time_elapsed         | 91         |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.13813569 |
# |    clip_fraction        | 0.364      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -33.3      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.97e+03   |
# |    n_updates            | 390        |
# |    policy_gradient_loss | 0.0151     |
# |    std                  | 0.735      |
# |    value_loss           | 9.36e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -8.62e+03  |
# | time/                   |            |
# |    fps                  | 891        |
# |    iterations           | 41         |
# |    time_elapsed         | 94         |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.05100088 |
# |    clip_fraction        | 0.496      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -33.3      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.19e+04   |
# |    n_updates            | 400        |
# |    policy_gradient_loss | 0.0188     |
# |    std                  | 0.735      |
# |    value_loss           | 1.22e+04   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -8.15e+03   |
# | time/                   |             |
# |    fps                  | 892         |
# |    iterations           | 42          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009444924 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.3       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.33e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00925    |
# |    std                  | 0.735       |
# |    value_loss           | 1.14e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -7.88e+03   |
# | time/                   |             |
# |    fps                  | 893         |
# |    iterations           | 43          |
# |    time_elapsed         | 98          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.026529994 |
# |    clip_fraction        | 0.331       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.3       |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.38e+04    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | 0.0154      |
# |    std                  | 0.735       |
# |    value_loss           | 1.3e+05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -7.82e+03   |
# | time/                   |             |
# |    fps                  | 894         |
# |    iterations           | 44          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.023582157 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.3       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.68e+04    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | 0.00462     |
# |    std                  | 0.735       |
# |    value_loss           | 1.01e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -7.53e+03   |
# | time/                   |             |
# |    fps                  | 895         |
# |    iterations           | 45          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.044307746 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33.2       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 47.8        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000741   |
# |    std                  | 0.727       |
# |    value_loss           | 371         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -7.28e+03   |
# | time/                   |             |
# |    fps                  | 896         |
# |    iterations           | 46          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.017589673 |
# |    clip_fraction        | 0.306       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -33         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.42e+04    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0017     |
# |    std                  | 0.727       |
# |    value_loss           | 6.72e+04    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -7.08e+03  |
# | time/                   |            |
# |    fps                  | 897        |
# |    iterations           | 47         |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01611121 |
# |    clip_fraction        | 0.142      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -33        |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.18e+05   |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00386   |
# |    std                  | 0.727      |
# |    value_loss           | 1.19e+05   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.51e+03     |
# |    ep_rew_mean          | -6.64e+03    |
# | time/                   |              |
# |    fps                  | 898          |
# |    iterations           | 48           |
# |    time_elapsed         | 109          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0075772232 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -33          |
# |    explained_variance   | 0            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.51e+04     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00557     |
# |    std                  | 0.726        |
# |    value_loss           | 1.13e+05     |
# ------------------------------------------
# Eval num_timesteps=100000, episode_reward=2577.74 +/- 0.00
# Episode length: 502.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 502         |
# |    mean_reward          | 2.58e+03    |
# | time/                   |             |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.014842324 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -32.9       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.97e+04    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00287    |
# |    std                  | 0.726       |
# |    value_loss           | 1.58e+05    |
# -----------------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 1.51e+03  |
# |    ep_rew_mean     | -6.41e+03 |
# | time/              |           |
# |    fps             | 896       |
# |    iterations      | 49        |
# |    time_elapsed    | 111       |
# |    total_timesteps | 100352    |
# ----------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | -6.2e+03   |
# | time/                   |            |
# |    fps                  | 895        |
# |    iterations           | 50         |
# |    time_elapsed         | 114        |
# |    total_timesteps      | 102400     |
# | train/                  |            |
# |    approx_kl            | 0.10086718 |
# |    clip_fraction        | 0.408      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -32.9      |
# |    explained_variance   | 5.96e-08   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.02e+04   |
# |    n_updates            | 490        |
# |    policy_gradient_loss | 0.034      |
# |    std                  | 0.726      |
# |    value_loss           | 1.29e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | -5.94e+03   |
# | time/                   |             |
# |    fps                  | 895         |
# ...
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.96e+03    |
# |    n_updates            | 24280       |
# |    policy_gradient_loss | -0.00371    |
# |    std                  | 0.669       |
# |    value_loss           | 1.87e+04    |
# -----------------------------------------
# Eval num_timesteps=4975000, episode_reward=-195.93 +/- 0.00
# Episode length: 502.00 +/- 0.00
# --------------------------------------
# | eval/                   |          |
# |    mean_ep_length       | 502      |
# |    mean_reward          | -196     |
# | time/                   |          |
# |    total_timesteps      | 4975000  |
# | train/                  |          |
# |    approx_kl            | 0.07218  |
# |    clip_fraction        | 0.331    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -29.1    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 8.8e+04  |
# |    n_updates            | 24290    |
# |    policy_gradient_loss | 0.0156   |
# |    std                  | 0.669    |
# |    value_loss           | 1.48e+05 |
# --------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | 1.93e+03 |
# | time/              |          |
# |    fps             | 520      |
# |    iterations      | 2430     |
# |    time_elapsed    | 9565     |
# |    total_timesteps | 4976640  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | 1.97e+03    |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 2431        |
# |    time_elapsed         | 9567        |
# |    total_timesteps      | 4978688     |
# | train/                  |             |
# |    approx_kl            | 0.012540951 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.78e+05    |
# |    n_updates            | 24300       |
# |    policy_gradient_loss | 0.00491     |
# |    std                  | 0.669       |
# |    value_loss           | 3.03e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | 2e+03       |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 2432        |
# |    time_elapsed         | 9569        |
# |    total_timesteps      | 4980736     |
# | train/                  |             |
# |    approx_kl            | 0.019155346 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.1       |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.64e+04    |
# |    n_updates            | 24310       |
# |    policy_gradient_loss | 0.00503     |
# |    std                  | 0.667       |
# |    value_loss           | 6.63e+04    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | 2.14e+03    |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 2433        |
# |    time_elapsed         | 9572        |
# |    total_timesteps      | 4982784     |
# | train/                  |             |
# |    approx_kl            | 0.061684325 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.64e+04    |
# |    n_updates            | 24320       |
# |    policy_gradient_loss | 0.00826     |
# |    std                  | 0.668       |
# |    value_loss           | 1.51e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | 2.18e+03    |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 2434        |
# |    time_elapsed         | 9574        |
# |    total_timesteps      | 4984832     |
# | train/                  |             |
# |    approx_kl            | 0.043016292 |
# |    clip_fraction        | 0.377       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29         |
# |    explained_variance   | 5.96e-08    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.13e+05    |
# |    n_updates            | 24330       |
# |    policy_gradient_loss | 0.0132      |
# |    std                  | 0.668       |
# |    value_loss           | 3.58e+05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | 2.24e+03    |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 2435        |
# |    time_elapsed         | 9576        |
# |    total_timesteps      | 4986880     |
# | train/                  |             |
# |    approx_kl            | 0.046962187 |
# |    clip_fraction        | 0.46        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.05e+04    |
# |    n_updates            | 24340       |
# |    policy_gradient_loss | 0.0214      |
# |    std                  | 0.668       |
# |    value_loss           | 1.66e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | 2.3e+03    |
# | time/                   |            |
# |    fps                  | 520        |
# |    iterations           | 2436       |
# |    time_elapsed         | 9579       |
# |    total_timesteps      | 4988928    |
# | train/                  |            |
# |    approx_kl            | 0.03460186 |
# |    clip_fraction        | 0.332      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -29        |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.31e+04   |
# |    n_updates            | 24350      |
# |    policy_gradient_loss | 0.0123     |
# |    std                  | 0.668      |
# |    value_loss           | 1.53e+05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | 2.34e+03   |
# | time/                   |            |
# |    fps                  | 520        |
# |    iterations           | 2437       |
# |    time_elapsed         | 9581       |
# |    total_timesteps      | 4990976    |
# | train/                  |            |
# |    approx_kl            | 0.06485237 |
# |    clip_fraction        | 0.493      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -29.1      |
# |    explained_variance   | -1.19e-07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.06e+04   |
# |    n_updates            | 24360      |
# |    policy_gradient_loss | 0.0169     |
# |    std                  | 0.67       |
# |    value_loss           | 2.39e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | 2.4e+03     |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 2438        |
# |    time_elapsed         | 9583        |
# |    total_timesteps      | 4993024     |
# | train/                  |             |
# |    approx_kl            | 0.060454942 |
# |    clip_fraction        | 0.361       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29.1       |
# |    explained_variance   | -1.19e-07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.14e+05    |
# |    n_updates            | 24370       |
# |    policy_gradient_loss | 0.0158      |
# |    std                  | 0.669       |
# |    value_loss           | 2.01e+05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | 2.5e+03    |
# | time/                   |            |
# |    fps                  | 521        |
# |    iterations           | 2439       |
# |    time_elapsed         | 9586       |
# |    total_timesteps      | 4995072    |
# | train/                  |            |
# |    approx_kl            | 0.01645387 |
# |    clip_fraction        | 0.357      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -29.1      |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 7.77e+04   |
# |    n_updates            | 24380      |
# |    policy_gradient_loss | 0.0137     |
# |    std                  | 0.669      |
# |    value_loss           | 2.05e+05   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.51e+03   |
# |    ep_rew_mean          | 2.48e+03   |
# | time/                   |            |
# |    fps                  | 521        |
# |    iterations           | 2440       |
# |    time_elapsed         | 9588       |
# |    total_timesteps      | 4997120    |
# | train/                  |            |
# |    approx_kl            | 0.08876053 |
# |    clip_fraction        | 0.312      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -29.1      |
# |    explained_variance   | 1.19e-07   |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.24e+05   |
# |    n_updates            | 24390      |
# |    policy_gradient_loss | 0.00576    |
# |    std                  | 0.669      |
# |    value_loss           | 2.79e+05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.51e+03    |
# |    ep_rew_mean          | 2.56e+03    |
# | time/                   |             |
# |    fps                  | 521         |
# |    iterations           | 2441        |
# |    time_elapsed         | 9590        |
# |    total_timesteps      | 4999168     |
# | train/                  |             |
# |    approx_kl            | 0.023352092 |
# |    clip_fraction        | 0.378       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -29         |
# |    explained_variance   | 0           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.19e+04    |
# |    n_updates            | 24400       |
# |    policy_gradient_loss | 0.015       |
# |    std                  | 0.667       |
# |    value_loss           | 6.04e+04    |
# -----------------------------------------
# Eval num_timesteps=5000000, episode_reward=-178.31 +/- 0.00
# Episode length: 502.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 502        |
# |    mean_reward          | -178       |
# | time/                   |            |
# |    total_timesteps      | 5000000    |
# | train/                  |            |
# |    approx_kl            | 0.07243343 |
# |    clip_fraction        | 0.273      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -29        |
# |    explained_variance   | 0          |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.59e+05   |
# |    n_updates            | 24410      |
# |    policy_gradient_loss | 0.00959    |
# |    std                  | 0.667      |
# |    value_loss           | 2.47e+05   |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | 2.71e+03 |
# | time/              |          |
# |    fps             | 521      |
# |    iterations      | 2442     |
# |    time_elapsed    | 9593     |
# |    total_timesteps | 5001216  |
# ---------------------------------
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='1.850 MB of 1.850 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>eval/mean_ep_length</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/mean_reward</td><td>▅▅▂▅▆▁▂█▁▂▁▁▁▁▁▁▁▁▁▂▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>global_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>rollout/ep_len_mean</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>rollout/ep_rew_mean</td><td>▁▃▅▅▅▆▇█▆▆▅▅▆▆▆▆▅▆▆▇▇▇▆▅▆▅▅▅▅▄▅▅▅▅▆█▆▅▅▅</td></tr><tr><td>time/fps</td><td>████████████████████▃▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▃▃</td></tr><tr><td>train/approx_kl</td><td>▁▁▂▃▂█▂▂▂▂▂▂▃▂▂▂▂▂▄▁▁▄▁▁▁▁▁▂▁▁▁▁▁▁▃▂▁▃▂▂</td></tr><tr><td>train/clip_fraction</td><td>▃▅▆▇▆▅▅▆▆▆▅▇█▅▇▆▆▆▅▅▄▇▁▁▅▆▆▆▁▅▅▂▅▅▇▅▂▇▆▅</td></tr><tr><td>train/clip_range</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/entropy_loss</td><td>▁▃▄▄▄▅▅▅▅▅▅▆▆▆▇▇▇▇▇▇▆▆▇▆▇▆▇▇▇███▇▇▇▆▆▆▆▆</td></tr><tr><td>train/explained_variance</td><td>▅▅▅▅▅▆▅▅▅▅█▅▅▅▅▁▅▁▅▅▅▅▅▁▁█▅▅▅▅▅▅▅▅▅▅▅▅▅▅</td></tr><tr><td>train/learning_rate</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/loss</td><td>▁▃▂▁▄▃▃▆▂▂▂▃▁▂▂▃▂▃▅█▃▃▂▁▄▂▃▂▁▁▂▅▁▁▄▄▁▂▂▅</td></tr><tr><td>train/policy_gradient_loss</td><td>▁▅▆▇▆▃▅▆▅▇▄▆█▄▇▆▄▆▅▅▄▇▃▂▆▄▄▆▂▄▅▃▄▅▆▅▃▅▅▅</td></tr><tr><td>train/std</td><td>█▆▅▄▄▃▃▃▃▄▃▂▂▂▂▁▁▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▂▃▃▃▃▃▄▄</td></tr><tr><td>train/value_loss</td><td>▁▃▂▁▅▂▇▇▂▂▂▃▃▂▃▃▃▄▄█▄▃▂▁▄▂▄▃▁▂▂▇▂▂▄▆▁▂▂▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>eval/mean_ep_length</td><td>502.0</td></tr><tr><td>eval/mean_reward</td><td>-178.31148</td></tr><tr><td>global_step</td><td>5001216</td></tr><tr><td>rollout/ep_len_mean</td><td>1509.0</td></tr><tr><td>rollout/ep_rew_mean</td><td>2709.07666</td></tr><tr><td>time/fps</td><td>521.0</td></tr><tr><td>train/approx_kl</td><td>0.07243</td></tr><tr><td>train/clip_fraction</td><td>0.273</td></tr><tr><td>train/clip_range</td><td>0.2</td></tr><tr><td>train/entropy_loss</td><td>-28.98191</td></tr><tr><td>train/explained_variance</td><td>0.0</td></tr><tr><td>train/learning_rate</td><td>0.0003</td></tr><tr><td>train/loss</td><td>158701.96875</td></tr><tr><td>train/policy_gradient_loss</td><td>0.00959</td></tr><tr><td>train/std</td><td>0.66684</td></tr><tr><td>train/value_loss</td><td>247473.28125</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fearless-elevator-4</strong>: <a href="https://wandb.ai/dennisfeng/cookiejars-scratch/runs/bzdlbvms" target="_blank">https://wandb.ai/dennisfeng/cookiejars-scratch/runs/bzdlbvms</a><br/>Synced 6 W&B file(s), 0 media file(s), 0 artifact file(s) and 4 other file(s)
# Find logs at: <code>./wandb/run-20220310_112244-bzdlbvms/logs</code>

# %%
env = CookieJarsEnv('train')
env.reset()
obs, rew, done, info = env.step(np.zeros(30))
obs
# Out:
# array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 8.28000031e+01, 4.04424896e+01,
#        4.08300018e+01, 2.87000008e+01, 1.57399998e+01, 5.62500000e+01,
#        5.85499992e+01, 7.92200012e+01, 2.46000004e+01, 2.84249992e+01,
#        4.12748222e+01, 6.91900024e+01, 1.18923080e+02, 2.36784744e+01,
#        2.87299995e+01, 2.09400005e+01, 1.25889099e+02, 6.45800018e+01,
#        4.27900009e+01, 6.26599998e+01, 3.55916023e+01, 3.08500004e+01,
#        1.79506645e+01, 6.11300011e+01, 4.96300011e+01, 3.17299995e+01,
#        4.50849571e+01, 3.12973557e+01, 5.40900002e+01, 3.20699997e+01,
#        1.00000000e+06])
